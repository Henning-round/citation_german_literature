# %% [markdown]
# # Create Subcorpora of Germanistik

# %%
from manager import load_obj, save_obj
from Homework import Homework
from pprint import pprint
from textblob import TextBlob
import csv

from nltk.corpus import stopwords
import re
import nltk
from nltk.tokenize import TweetTokenizer
import string
import numpy as np
import pickle

from tqdm.notebook import tqdm

# %%
works = load_obj("works_references")

# %%
subcorpora =[]

for work in works:
    if work.subject.split(" ")[0].lower() == "germanistik":
        subcorpora.append(work)

# %%
save_obj(subcorpora, "germanistik")

# %%
germanistik=[]
for work in works:
    if work.subject.split(" ")[0].lower() == "germanistik":
        germanistik.append(work)

# %%
subcorpora = load_obj("germanistik")

# %%
pprint(vars(subcorpora[1]))
# Out:
# {'author': 'Axel Schütte (Autor:in)',
#  'category': 'Hausarbeit, 2022',
#  'grade': 'none',
#  'institution': 'SRH Fachhochschule Hamm',
#  'isbn': 'none',
#  'lang': 'none',
#  'link': 'https://www.hausarbeiten.de/document/1187831',
#  'only_text': 'none',
#  'pages': '43',
#  'pages_displayed': 'none',
#  'price': 'Kostenlos',
#  'references': 'none',
#  'subject': 'Informatik - Wirtschaftsinformatik',
#  'tags': ' erp-systeme funktionen schnittstellen ',
#  'text_html': 'none',
#  'title': 'Wie sind ERP-Systeme aufgebaut, über welche Funktionen und '
#           'Schnittstellen verfügen sie?'}

# %%
with open(r"C:\Users\Tim\Desktop\bachelorarbeit\data\germanistik.csv", 'w', newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["author","category","grade", "institution", "isbn", "lang", "link", "only_text", "pages", "pages_displayed", "price", "references", "subject", "tags", "text_html", "title"])  
    for work in subcorpora:
        print(type(work.isbn))
        writer.writerow([work.author,work.category,work.grade,work.institution,work.isbn,work.lang,work.link,work.only_text,work.pages,work.pages_displayed,work.price,work.references,work.subject,work.tags,work.text_html,work.title])
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %% [markdown]
# # Save subcorpora for python 2

# %%
works = load_obj("subcorpora_language")

import json

for work in works:
    name = work.link.split("/")[-1]
    with open(fr'C:\Users\Tim\Desktop\bachelorarbeit\jsons\\{name}.json', 'w',  encoding='utf8' ) as fp:
        json.dump(work.__dict__, fp)

# %%
for work in works:
    if work.link == "https://www.hausarbeiten.de/document/97247":
        print(repr(work.text_html))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 for work in works:
#       2     if work.link == "https://www.hausarbeiten.de/document/97247":
#       3         print(repr(work.text_html))
#
# NameError: name 'works' is not defined
